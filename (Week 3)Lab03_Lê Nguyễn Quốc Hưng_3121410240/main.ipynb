# %% [markdown]
# # DIAGNOSIS OF DIABETES

# %% [markdown]
# ## Introduction

# %% [markdown]
# According to dataset from kaggle(https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database)
# .The features present in the dataset are:
# - Pregnancies
# - Glucose
# - BloodPressure
# - SkinThickness
# - Insulin
# - BMI
# - DiabetesPedigreeFunction
# - Age
# - Outcome

# %%
# import pandas, matplotlib.pyplot, seabon, numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset (Diagnosis of diabetes)

# %%
# To be more specific we need to add column base on dataset
columns = [
    "Pregnancies",
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age",
    "Outcome",
]

df = pd.read_csv("../Source Diagnosis of diabetes/pima-indians-diabetes.csv",header=None,names=columns)
print(df.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ## Non-graphie EDA

# %% [markdown]
# ### Dataframe data

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# ### Print first 5 line

# %%
# First 5 line data
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# ### Check edge info of data in dataframe

# %%
# Info of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# ### Check null/na values for each columns name

# %%
# check null value
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ### Describe the dataframe

# %%
# Describe the dataframe
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# ### Watch the correlation between variable

# %%
# Correlation between variable
df.corr()

"""
Glucose	Outcome	0.466	Tương quan dương khá mạnh → Glucose cao thường liên quan đến nguy cơ tiểu đường
BMI	Outcome	0.19	Tương quan dương vừa phải → Chỉ số BMI cao có thể liên quan đến tiểu đường
Age	Pregnancies	0.544	Tương quan dương mạnh → Người lớn tuổi thường có nhiều lần mang thai hơn
SkinThickness	BMI	0.392	Tương quan dương vừa phải → Da dày hơn thường đi kèm với BMI cao
"""
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# ###  class(Age) is balance

# %%
# It can be optional choice due to age between 22 and 81
df["Age"].value_counts()
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 36    16
# 38    16
# 32    16
# 45    15
# 34    14
# 46    13
# 40    13
# 43    13
# 39    12
# 35    10
# 44     8
# 50     8
# 51     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 60     5
# 53     5
# 57     5
# 48     5
# 63     4
# 66     4
# 55     4
# 62     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: count, dtype: int64

# %% [markdown]
# ## **Graphical EDA**

# %% [markdown]
# ### Are the class(Age) is balance (using 3 library numpy, pandas and matplotlib)

# %% [markdown]
# #### Using Seaborn

# %%
sns.countplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %% [markdown]
# #### Using pandas

# %%
df["Age"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# #### Using matplotlib

# %%
counts = df["Age"].value_counts()
plt.bar(counts.index,counts.values)
# Out:
# <BarContainer object of 52 artists>

# %% [markdown]
# #### Conclusion

# %% [markdown]
# - Age is not balanced
# - Not suitable for pie, bar charts for it's huge columns data
# - "Age" may not be processing because it's numberical data ( such as 22,31 year olds)

# %% [markdown]
# ## Comparasion graph (We set data["Age"] and data["Pregnancies"] for the highest correlation)

# %% [markdown]
# ### Scatterplot using pandas

# %%
df.plot.scatter('Age','Pregnancies')
# Out:
# <Axes: xlabel='Age', ylabel='Pregnancies'>

# %% [markdown]
# ### Scatterplot using matplotlib

# %%
plt.scatter(df["Age"],df["Pregnancies"])

# %%
# Make it clear by
plt.plot('Age', 'Pregnancies', data=df, marker='.',linestyle='none')

# %% [markdown]
# ### Scatterplot using seaborn

# %%
sns.scatterplot(x = df['Age'], y = df['Pregnancies'])
# Out:
# <Axes: xlabel='Age', ylabel='Pregnancies'>

# %%
sns.scatterplot(x = 'Age', y = 'Pregnancies', hue=df['Outcome'], data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Pregnancies'>

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - Phân bố tuổi (Age):
#
# Dữ liệu tập trung chủ yếu trong khoảng 20–60 tuổi.
#
# Sau 60 tuổi số lượng điểm rất ít, nghĩa là mẫu khảo sát cho người lớn tuổi ít hơn.
#
# - Phân bố số lần mang thai (Pregnancies):
#
# Hầu hết các giá trị nằm trong khoảng 0–10 lần mang thai, nhưng có một số trường hợp ngoại lệ đến tận 17 lần.
#
# - So sánh Outcome (0 và 1):
#
# Outcome = 0 (màu xanh): có nhiều điểm hơn ở mức số lần mang thai thấp (0–5 lần).
#
# Outcome = 1 (màu cam): xuất hiện nhiều ở tuổi trung niên (30–50 tuổi) và thường có số lần mang thai từ 2–10.
#
# - Xu hướng tổng quát:
#
# Người nhiều lần mang thai thường rơi vào nhóm Outcome = 1 nhiều hơn so với nhóm ít lần mang thai.
#
# Tuy nhiên, cũng có khá nhiều người Outcome = 0 ngay cả khi mang thai nhiều lần → nghĩa là không có mối quan hệ tuyến tính rõ rệt, chỉ là có xu hướng.

# %% [markdown]
# ## Corellogram

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue="Outcome")

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - Phân bố tuổi (Age):
#
# Dữ liệu tập trung chủ yếu trong khoảng 20–60 tuổi.
#
# Sau 60 tuổi số lượng điểm rất ít, nghĩa là mẫu khảo sát cho người lớn tuổi ít hơn.
#
# - Phân bố số lần mang thai (Pregnancies):
#
# Hầu hết các giá trị nằm trong khoảng 0–10 lần mang thai, nhưng có một số trường hợp ngoại lệ đến tận 17 lần.
#
# - So sánh Outcome (0 và 1):
#
# Outcome = 0 (màu xanh): có nhiều điểm hơn ở mức số lần mang thai thấp (0–5 lần).
#
# Outcome = 1 (màu cam): xuất hiện nhiều ở tuổi trung niên (30–50 tuổi) và thường có số lần mang thai từ 2–10.
#
# - Xu hướng tổng quát:
#
# Người nhiều lần mang thai thường rơi vào nhóm Outcome = 1 nhiều hơn so với nhóm ít lần mang thai.
#
# Tuy nhiên, cũng có khá nhiều người Outcome = 0 ngay cả khi mang thai nhiều lần → nghĩa là không có mối quan hệ tuyến tính rõ rệt, chỉ là có xu hướng.

# %% [markdown]
# ## Heatmap

# %%
fig = plt.figure(figsize = (15,9))
sns.heatmap(df.corr(), cmap='Blues', annot = True);

# %% [markdown]
# **Histograms and distributions**

# %%
df.hist();

# %% [markdown]
# **Boxplots and violins**

# %%
sns.boxplot(x='Age', y='Pregnancies', data=df)
# Out:
# <Axes: xlabel='Age', ylabel='Pregnancies'>

# %%
df.boxplot(by="Outcome", figsize=(12, 8));

# %%
sns.violinplot(x='Outcome', y='Pregnancies', data=df)
# Out:
# <Axes: xlabel='Outcome', ylabel='Pregnancies'>
